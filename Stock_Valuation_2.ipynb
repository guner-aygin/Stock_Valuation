# %% [markdown]
# # Stock Valuation 2
#
# This project aims to create a portfolio of stocks to buy. The priority is not to pick winning stocks, but to avoid picking losing stocks. I will aim to do this by assessing the value, growth, income and momentum of the companies in the US and UK stock market, and make a portfolio of these companies.

# %% [markdown]
# # Stock Analysis
#
# ### Information Technology Sector

# %%
import pandas as pd
import yfinance as yf
import numpy as np
import logging

# Configure logging
logging.basicConfig(level=logging.ERROR, format='%(levelname)s:%(message)s')

# Load the CSV file containing all US companies
df = pd.read_csv('us_stock_data.csv')

# Define the function to calculate alpha based on the notebook's logic
def calculate_alpha(stock_returns, market_returns, risk_free_rate=0.03):
    # Align the series by their dates
    returns = pd.DataFrame({'stock': stock_returns, 'market': market_returns}).dropna()
    
    # Ensure there are enough data points to calculate covariance and variance
    if len(returns) < 2:
        return np.nan
    
    # Calculate the excess returns
    returns['excess_stock'] = returns['stock'] - risk_free_rate / 252
    returns['excess_market'] = returns['market'] - risk_free_rate / 252
    
    # Calculate the covariance and variance
    covariance = np.cov(returns['excess_stock'], returns['excess_market'])[0, 1]
    variance = np.var(returns['excess_market'])
    
    if variance == 0:
        return np.nan
    
    # Calculate beta
    beta = covariance / variance
    
    # Calculate alpha
    alpha = (returns['excess_stock'].mean() - beta * returns['excess_market'].mean()) * 252
    return alpha

# Function to fetch P/E ratio, Alpha, Volatility, Market Cap, and price appreciation for a list of tickers
def fetch_metrics(tickers):
    metrics = {
        'symbol': [],
        'P/E Ratio': [],
        'Alpha (%)': [],
        'Volatility (%)': [],
        'Market Cap (B)': [],
        '6 Month Appreciation (%)': []
    }

    for ticker in tickers:
        try:
            stock = yf.Ticker(ticker)
            hist = stock.history(period="10y")
            
            if hist.empty:
                logging.error(f"{ticker}: No historical data found.")
                continue
            
            # P/E Ratio
            pe_ratio = stock.info.get('forwardPE', None)
            if pe_ratio is None or pe_ratio <= 0 or pe_ratio >= 25:
                continue
            
            # Calculate 6 month appreciation
            if len(hist) < 126:
                logging.error(f"{ticker}: Not enough data for 6 months calculation.")
                continue
            
            six_month_appreciation = ((hist['Close'][-1] - hist['Close'][-126]) / hist['Close'][-126]) * 100
            if six_month_appreciation <= 0:
                continue
            
            # Calculate Alpha
            stock_returns = hist['Close'].pct_change().dropna()
            market_returns = yf.Ticker('^GSPC').history(period="10y")['Close'].pct_change().dropna()
            
            if market_returns.empty:
                logging.error(f"{ticker}: No market data found for S&P 500.")
                continue
            
            alpha = calculate_alpha(stock_returns, market_returns) * 100
            
            # Calculate Volatility
            volatility = stock_returns.std() * (252 ** 0.5) * 100
            
            # Market Cap in billions
            market_cap = stock.info.get('marketCap', None)
            if market_cap is None:
                continue
            market_cap_b = market_cap / 1e9

            metrics['symbol'].append(ticker)
            metrics['P/E Ratio'].append(pe_ratio)
            metrics['Alpha (%)'].append(alpha)
            metrics['Volatility (%)'].append(volatility)
            metrics['Market Cap (B)'].append(market_cap_b)
            metrics['6 Month Appreciation (%)'].append(six_month_appreciation)
        
        except Exception as e:
            logging.error(f"Error processing {ticker}: {e}")

    return pd.DataFrame(metrics)

# Use tickers from the loaded dataframe
tickers = df['symbol'].unique()

# Fetch the metrics
stock_metrics_df = fetch_metrics(tickers)  # Limiting to first 50 tickers for example purposes

# Order the stocks based on Market Cap
stock_metrics_df = stock_metrics_df.sort_values(by='Market Cap (Billion $)', ascending=False)

# Display the table
print(stock_metrics_df)

# Optionally, save the table to a CSV file
stock_metrics_df.to_csv('stock_metrics.csv', index=False)
# Out:
# ERROR:Error processing AEYE: '<=' not supported between instances of 'str' and 'int'
# ERROR:Error processing AHI: '<=' not supported between instances of 'str' and 'int'
# ERROR:Error processing ALTG: '<=' not supported between instances of 'str' and 'int'
# ERROR:Error processing ARAY: '<=' not supported between instances of 'str' and 'int'
# ERROR:AS: Not enough data for 6 months calculation.
# ERROR:Error processing AVAH: '<=' not supported between instances of 'str' and 'int'
# ERROR:Error processing BCOV: '<=' not supported between instances of 'str' and 'int'
# ERROR:BFX: No data found, symbol may be delisted
# ERROR:BFX: No historical data found.
# ERROR:BODY: No data found, symbol may be delisted
# ERROR:BODY: No historical data found.
# ERROR:BPTS: No data found, symbol may be delisted
# ERROR:BPTS: No historical data found.
# ERROR:BTSG: Not enough data for 6 months calculation.
# ERROR:CTRI: Not enough data for 6 months calculation.
# ERROR:Error processing DDD: '<=' not supported between instances of 'str' and 'int'
# ERROR:DHCA: No data found, symbol may be delisted
# ERROR:DHCA: No historical data found.
# ERROR:DSKE: No data found, symbol may be delisted
# ERROR:DSKE: No historical data found.
# ERROR:ENCP: No data found, symbol may be delisted
# ERROR:ENCP: No historical data found.
# ERROR:FICV: No data found, symbol may be delisted
# ERROR:FICV: No historical data found.
# ERROR:Error processing FLL: '<=' not supported between instances of 'str' and 'int'
# ERROR:FXCO: No data found, symbol may be delisted
# ERROR:FXCO: No historical data found.
# ERROR:GRCL: No data found, symbol may be delisted
# ERROR:GRCL: No historical data found.
# ERROR:INPX: No data found, symbol may be delisted
# ERROR:INPX: No historical data found.
# ERROR:KSPI: Not enough data for 6 months calculation.
# ERROR:LBBB: No data found, symbol may be delisted
# ERROR:LBBB: No historical data found.
# ERROR:LCAA: No data found, symbol may be delisted
# ERROR:LCAA: No historical data found.
# ERROR:LHC: No data found, symbol may be delisted
# ERROR:LHC: No historical data found.
# ERROR:LOBO: Not enough data for 6 months calculation.
# ERROR:Error processing MARA: '<=' not supported between instances of 'str' and 'int'
# ERROR:MBTC: No data found, symbol may be delisted
# ERROR:MBTC: No historical data found.
# ERROR:NGMS: No data found, symbol may be delisted
# ERROR:NGMS: No historical data found.
# ERROR:NRAC: No data found, symbol may be delisted
# ERROR:NRAC: No historical data found.
# ERROR:Error processing NXGL: '<=' not supported between instances of 'str' and 'int'
# ERROR:OTEC: No data found, symbol may be delisted
# ERROR:OTEC: No historical data found.
# ERROR:PACS: Not enough data for 6 months calculation.
# ERROR:PARAP: No data found, symbol may be delisted
# ERROR:PARAP: No historical data found.
# ERROR:Error processing PET: '<=' not supported between instances of 'str' and 'int'
# ERROR:Error processing PGRU: '<=' not supported between instances of 'str' and 'int'
# ERROR:PHXM: No data found, symbol may be delisted
# ERROR:PHXM: No historical data found.
# ERROR:Error processing POWW: '<=' not supported between instances of 'str' and 'int'
# ERROR:RACY: No data found, symbol may be delisted
# ERROR:RACY: No historical data found.
# ERROR:RMGC: No data found, symbol may be delisted
# ERROR:RMGC: No historical data found.
# ERROR:ROI: No data found, symbol may be delisted
# ERROR:ROI: No historical data found.
# ERROR:ROSS: No data found, symbol may be delisted
# ERROR:ROSS: No historical data found.
# ERROR:SASI: No data found, symbol may be delisted
# ERROR:SASI: No historical data found.
# ERROR:SDHC: Not enough data for 6 months calculation.
# ERROR:SOLO: No data found, symbol may be delisted
# ERROR:SOLO: No historical data found.
# ERROR:SOLV: Not enough data for 6 months calculation.
# ERROR:Error processing VERI: '<=' not supported between instances of 'str' and 'int'
# ERROR:VIAO: No data found, symbol may be delisted
# ERROR:VIAO: No historical data found.
# ERROR:VJET: No data found, symbol may be delisted
# ERROR:VJET: No historical data found.
# ERROR:XPDB: No data found, symbol may be delisted
# ERROR:XPDB: No historical data found.
# ERROR:Error processing ZH: '<=' not supported between instances of 'str' and 'int'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/f6/ysbvf32j6ks_1h83gmlfzghw0000gn/T/ipykernel_35742/2362877939.py in ?()
# --> 111 import pandas as pd
#     112 import yfinance as yf
#     113 import numpy as np
#     114 import logging
#
# ~/stock_env/lib/python3.9/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6754         elif len(by):
#    6755             # len(by) == 1
#    6756
#    6757             by = by[0]
# -> 6758             k = self._get_label_or_level_values(by, axis=axis)
#    6759
#    6760             # need to rewrap column in Series to apply key function
#    6761             if key is not None:
#
# ~/stock_env/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1774             values = self.xs(key, axis=other_axes[0])._values
#    1775         elif self._is_level_reference(key, axis=axis):
#    1776             values = self.axes[axis].get_level_values(key)._values
#    1777         else:
# -> 1778             raise KeyError(key)
#    1779
#    1780         # Check for duplicates
#    1781         if values.ndim > 1:
#
# KeyError: 'Market Cap (Billion $)'
